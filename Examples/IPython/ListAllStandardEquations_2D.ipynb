# %%
import os, sys, inspect

# ensure pyeq2 can be imported
import os, sys
currentDir = os.getcwd()
if -1 != currentDir.find('pyeq2-master'): raise Exception('Please rename git checkout directory from "pyeq2-master" to "pyeq2"')
pyeq2IimportDir =  os.path.dirname(os.path.dirname(os.path.dirname(currentDir)))
if pyeq2IimportDir not in sys.path: sys.path.append(pyeq2IimportDir)
import pyeq3

# %%
htmlToReturn = '' # build this as we progress

htmlToReturn += '<table border=1>'

for submodule in inspect.getmembers(pyeq3.Models_2D): # 2D equations in this example
    if inspect.ismodule(submodule[1]):
        for equationClass in inspect.getmembers(submodule[1]):
            if inspect.isclass(equationClass[1]):
                for extendedVersionName in ['Default', 'Offset']:
                    if (-1 != extendedVersionName.find('Offset')) and (equationClass[1].autoGenerateOffsetForm == False):
                        continue

                    equation = equationClass[1]('SSQABS', extendedVersionName)
                    htmlToReturn += '<tr>'
                    htmlToReturn += '<td nowrap>2D ' + submodule[0] + '</td>'
                    htmlToReturn += '<td nowrap>' + equation.GetDisplayName() + '</td>'
                    htmlToReturn += '<td nowrap>' + equation.GetDisplayHTML() + '</td>'
                    htmlToReturn += '</tr>'

htmlToReturn += '</table>'

from IPython.core.display import HTML
HTML(htmlToReturn)
# Out:
# <table border=1><tr><td nowrap>2D BioScience</td><td nowrap>Aphid Population Growth</td><td nowrap>N(t) = a * exp(bt) * (1 + c * exp(bt))<sup>-2</sup></td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Aphid Population Growth With Offset</td><td nowrap>N(t) = a * exp(bt) * (1 + c * exp(bt))<sup>-2</sup> + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>von Bertalanffy Growth</td><td nowrap>L(t) = L<sub>inf</sub> * (1.0 - exp(-K * (t-t<sub>zero</sub>)))</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>von Bertalanffy Growth With Offset</td><td nowrap>L(t) = L<sub>inf</sub> * (1.0 - exp(-K * (t-t<sub>zero</sub>))) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Beverton-Holt A</td><td nowrap>y = r / (1 + ((r-1)/K) * x)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Beverton-Holt A With Offset</td><td nowrap>y = r / (1 + ((r-1)/K) * x) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Beverton-Holt B</td><td nowrap>y = rx / (1 + ((r-1)/K) * x)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Beverton-Holt B With Offset</td><td nowrap>y = rx / (1 + ((r-1)/K) * x) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>BioScience A</td><td nowrap>y = a * (1.0 - (b * c<sup>x</sup>))</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>BioScience A With Offset</td><td nowrap>y = a * (1.0 - (b * c<sup>x</sup>)) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>BioScience B</td><td nowrap>y = a * (1.0 -(1.0 + (x/b)<sup>c</sup>)<sup>-1.0 * d</sup>)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>BioScience B With Offset</td><td nowrap>y = a * (1.0 -(1.0 + (x/b)<sup>c</sup>)<sup>-1.0 * d</sup>) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Cellular Conductance</td><td nowrap>g = p3/(1+exp((v-p1)/p2)) + p4*exp((v-45)/p5)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Cellular Conductance With Offset</td><td nowrap>g = p3/(1+exp((v-p1)/p2)) + p4*exp((v-45)/p5) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Derek Duncan Custom Equation</td><td nowrap>y = a / (1 + exp(-1/b*(x-c)))<sup>d</sup></td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Derek Duncan Custom Equation With Offset</td><td nowrap>y = a / (1 + exp(-1/b*(x-c)))<sup>d</sup> + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Dose-Response A</td><td nowrap>y = b + (a-b) / (1 + 10<sup>x-c</sup>)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Dose-Response B</td><td nowrap>y = b + (a-b) / (1 + 10<sup>c-x</sup>)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Dose-Response C</td><td nowrap>y = b + (a-b) / (1 + 10<sup>d*(x-c)</sup>)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Dose-Response D</td><td nowrap>y = b + (a-b) / (1 + 10<sup>d*(c-x)</sup>)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Dose-Response E</td><td nowrap>y = b + (a-b) / (1 + (x/c)<sup>d</sup>)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Generalized Negative Exponential</td><td nowrap>y = a * (1.0 - exp(-bx))<sup>c</sup></td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Generalized Negative Exponential With Offset</td><td nowrap>y = a * (1.0 - exp(-bx))<sup>c</sup> + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Generalized Product Accumulation</td><td nowrap>y = a(b-x) / (c + (b-x)) + d(b-x) + f</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>Generalized Substrate Depletion</td><td nowrap>y = ax / (b + x) - cx - d</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>High-Low Affinity</td><td nowrap>y = abx / (1+bx)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>High-Low Affinity With Offset</td><td nowrap>y = abx / (1+bx) + Offset</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>High-Low Affinity Double</td><td nowrap>y = abx / (1+bx) + cdx / (1+dx)</td></tr><tr><td nowrap>2D BioScience</td><td nowrap>High-Low Affinity Double With Offset</td><td nowrap>y = abx / (1+bx) + cdx / (1+dx) + Offset</td></tr><tr><td nowrap>2D Bi ...
